# %%
import csv
from bs4 import BeautifulSoup
import lxml
import requests

# %%
page = requests.get("https://www.yallakora.com/match-center/%D9%85%D8%B1%D9%83%D8%B2-%D8%A7%D9%84%D9%85%D8%A8%D8%A7%D8%B1%D9%8A%D8%A7%D8%AA?date=3/8/2023#days")

def main(page):
    src =page.content   # all code > byte code
    soup=BeautifulSoup(src, 'lxml')
    print(soup)

main(page)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <!-- strat: Chartbeat-->
# <script type="text/javascript">
#         var _sf_startpt = (new Date()).getTime()
#     </script>
# <!-- end: chartbeat-->
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="initial-scale=1,maximum-scale=1,user-scalable=no, width=device-width" name="viewport"/>
# <!-- Download App Notification -->
# <meta content="app-id=377713182, affiliate-data=myAffiliateData, app-argument=value" name="apple-itunes-app" property="apple-itunes-app"/>
# <meta content="app-id=com.inventivotech.yallakora" name="google-play-app" property="google-play-app"/>
# <meta content="max-snippet:-1, max-image-preview:large,max-video-preview:0" name="robots"/>
# <link href="https://www.yallakora.com//Images/Logo/favicon.ico?ver=1" rel="icon" type="image/ico"/>
# ...
